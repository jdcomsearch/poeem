# %% [markdown]
# # Poeem Tutorial
#
# In this notebook, we will demonstrate how to use *poeem* to jointly learn embedding index together with retrieval model. In addition to learning how to use *poeem*, you will also learn
#
# - Write a simple embedding retrieval model
# - Nearest neighbor search with brute force
# - Approximate nearest neighbor (ANN) search with Faiss - a Facebook open source library for ANN search with separately already learned embeddings
# - Approximate nearest neighbor (ANN) search with *Poeem*

# %%
import tensorflow as tf
import numpy as np
import poeem

# %% [markdown]
# So far, *poeem* only supports Tensorflow 1.15, other tensorflow versions have not been tested. Users may need to make minor changes accordingly to let it run on other versions of Tensorflow.

# %%
assert tf.__version__[:4] == '1.15'

# %% [markdown]
# ## Toy data
#
# To demonstrate how *poeem* works, here we synthesizes a toy data for a quick tutorial. More real-world and larger data set tutorial is given [here]()
#
# In this toy data, the query and item are both represented as numerical ID numbers, which is simply also the row indices to their embedding matrices. Specifically,
#
# - a query is an integer number ranging from 0 to *vocab_size* (10,000 in this tutorial)
# - a item is an integer number ranging from 0 to *vocab_size* (10,000 in this tutorial)
# - a query ending with last two digits as *xy*, will retrieve items ending with last 4 digits as *abcd* where any two of them equal to x and y, e.g., a=x, b=y, or c=x, b=y and so on.

# %%
N = 1000000  # number of training examples
VOCAB_SIZE = 10000

# %%
# simulate the data
query = np.random.randint(0, high=VOCAB_SIZE, size=N)
item = np.random.randint(0, high=VOCAB_SIZE, size=N)

d, c, b, a = item % 10, (item // 10) % 10, (item // 100) % 10, (item // 1000) % 10

def get_xy(a, axis):
    idx = np.random.rand(*a.shape).argsort(axis=axis)
    shuffled = np.take_along_axis(a,idx,axis=axis)
    return shuffled[:, 0], shuffled[:, 1]

x, y = get_xy(np.stack([a, b, c, d], axis=1), 1)
query = (query // 100) * 100 + x * 10 + y

# %% [markdown]
# Let's take a look at the synthetic data to make sure the pattern is correct.

# %%
[query[:10], item[:10]]
# Out:
# [array([ 336, 2328, 9134,  902, 8923, 1868,  168, 9344, 3081, 4668]),
#  array([3679, 1282, 5334,  320, 3192, 9683, 6681, 4244, 8616, 9687])]

# %% [markdown]
# ## Training

# %% [markdown]
# In this training section, we will write a very simple embedding retrieval model for demonstration. Please be advised that this embedding model is solely for tutorial but not immediately applicable to real-world industrial systems yet where more practical techniques are necessary.
#
# First let's define some hyperparameters

# %%
BATCH_SIZE = 128
LEARNING_RATE = 0.1
EPOCH = 3
EMB_DIM = 64

# %% [markdown]
# Second, let's leverage the Tensorflow Estimator API with custom model_fn where we can define the model by ourselves and reuse the other convenient utilities to train the model.
#
# The queries and items are represented as separate embeddings.

# %%
def model_fn(features, labels, mode):
    query_column = tf.feature_column.embedding_column(
        tf.feature_column.categorical_column_with_vocabulary_list(
            key='query',
            vocabulary_list=range(VOCAB_SIZE),
            dtype=tf.int32),
        dimension=EMB_DIM)
    item_column = tf.feature_column.embedding_column(
        tf.feature_column.categorical_column_with_vocabulary_list(
            key='item',
            vocabulary_list=range(VOCAB_SIZE),
            dtype=tf.int32),
        dimension=EMB_DIM)
    
    query_emb = tf.feature_column.input_layer(features, [query_column])
    item_emb = tf.feature_column.input_layer(features, [item_column])

    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(
            mode, predictions={'query': query_emb, 'item': item_emb})

    def cosine(a, b):
        a = tf.nn.l2_normalize(a, axis=1)
        b = tf.nn.l2_normalize(b, axis=1)
        return tf.matmul(a, b, transpose_b=True)

    scores = cosine(query_emb, item_emb)

    batch_size = tf.shape(query_emb)[0]
    loss = tf.reduce_sum(
        tf.nn.softmax_cross_entropy_with_logits_v2(
            labels=tf.eye(batch_size),
            logits=scores * 30))  # 1/30 is softmax temperature. Not carefully tune.

    optimizer = tf.train.AdagradOptimizer(LEARNING_RATE)
    train_op = optimizer.minimize(loss, global_step=tf.train.get_global_step())

    return tf.estimator.EstimatorSpec(
        mode, loss=loss, train_op=train_op, predictions={'query': query_emb, 'item': item_emb})

# %% [markdown]
# Third, let's define an input function that feeds data into the *model_fn* defined above.

# %%
def input_fn():
    dataset = tf.data.Dataset.from_tensor_slices({'query': query.astype(np.int32), 'item': item.astype(np.int32)})
    dataset = dataset.shuffle(buffer_size=1000).batch(BATCH_SIZE).repeat(EPOCH)
    return dataset

# %% [markdown]
# Finally, we are ready to train the model with the above defined *model_fn* and *input_fn* by simply two lines.

# %%
retrieval_model = tf.estimator.Estimator(model_fn=model_fn)
retrieval_model.train(input_fn=input_fn)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpevc_odlj
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpevc_odlj', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f592f328668>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/tensorflow_core/python/feature_column/feature_column.py:206: EmbeddingColumn._get_dense_tensor (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:3182: VocabularyListCategoricalColumn._get_sparse_tensors (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/tensorflow_core/python/feature_column/feature_column.py:2158: VocabularyListCategoricalColumn._transform_feature (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:3122: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/tensorflow_core/python/ops/embedding_ops.py:802: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/tensorflow_core/python/feature_column/feature_column.py:207: EmbeddingColumn._variable_shape (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/tensorflow_core/python/training/adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpevc_odlj/model.ckpt.
# INFO:tensorflow:loss = 1294.9807, step = 0
# INFO:tensorflow:global_step/sec: 183.185
# INFO:tensorflow:loss = 1272.829, step = 100 (0.547 sec)
# INFO:tensorflow:global_step/sec: 247.151
# INFO:tensorflow:loss = 1383.0375, step = 200 (0.405 sec)
# INFO:tensorflow:global_step/sec: 239.976
# INFO:tensorflow:loss = 1381.3633, step = 300 (0.417 sec)
# INFO:tensorflow:global_step/sec: 248.61
# INFO:tensorflow:loss = 1315.2444, step = 400 (0.402 sec)
# INFO:tensorflow:global_step/sec: 227.463
# INFO:tensorflow:loss = 1435.6741, step = 500 (0.439 sec)
# INFO:tensorflow:global_step/sec: 219.324
# INFO:tensorflow:loss = 1298.0303, step = 600 (0.456 sec)
# INFO:tensorflow:global_step/sec: 227.36
# INFO:tensorflow:loss = 1311.049, step = 700 (0.440 sec)
# INFO:tensorflow:global_step/sec: 221.884
# INFO:tensorflow:loss = 1275.5012, step = 800 (0.450 sec)
# INFO:tensorflow:global_step/sec: 258.117
# INFO:tensorflow:loss = 1230.2657, step = 900 (0.389 sec)
# INFO:tensorflow:global_step/sec: 217.861
# INFO:tensorflow:loss = 1288.6962, step = 1000 (0.459 sec)
# INFO:tensorflow:global_step/sec: 218.574
# INFO:tensorflow:loss = 1230.6832, step = 1100 (0.456 sec)
# INFO:tensorflow:global_step/sec: 214.079
# INFO:tensorflow:loss = 1333.616, step = 1200 (0.467 sec)
# INFO:tensorflow:global_step/sec: 222.09
# INFO:tensorflow:loss = 1347.0466, step = 1300 (0.451 sec)
# INFO:tensorflow:global_step/sec: 224.714
# INFO:tensorflow:loss = 1301.5557, step = 1400 (0.445 sec)
# INFO:tensorflow:global_step/sec: 225.291
# INFO:tensorflow:loss = 1330.6729, step = 1500 (0.443 sec)
# INFO:tensorflow:global_step/sec: 239.055
# INFO:tensorflow:loss = 1208.023, step = 1600 (0.418 sec)
# INFO:tensorflow:global_step/sec: 228.451
# INFO:tensorflow:loss = 1216.2445, step = 1700 (0.438 sec)
# INFO:tensorflow:global_step/sec: 240.084
# INFO:tensorflow:loss = 1345.5929, step = 1800 (0.416 sec)
# INFO:tensorflow:global_step/sec: 243.383
# INFO:tensorflow:loss = 1246.9193, step = 1900 (0.411 sec)
# INFO:tensorflow:global_step/sec: 225.155
# INFO:tensorflow:loss = 1207.915, step = 2000 (0.446 sec)
# INFO:tensorflow:global_step/sec: 224.472
# INFO:tensorflow:loss = 1236.1348, step = 2100 (0.444 sec)
# INFO:tensorflow:global_step/sec: 225.865
# INFO:tensorflow:loss = 1263.5298, step = 2200 (0.443 sec)
# INFO:tensorflow:global_step/sec: 217.653
# INFO:tensorflow:loss = 1087.4286, step = 2300 (0.462 sec)
# INFO:tensorflow:global_step/sec: 215.235
# INFO:tensorflow:loss = 1140.6746, step = 2400 (0.463 sec)
# INFO:tensorflow:global_step/sec: 226.735
# INFO:tensorflow:loss = 1152.6075, step = 2500 (0.440 sec)
# INFO:tensorflow:global_step/sec: 226.28
# INFO:tensorflow:loss = 1258.6501, step = 2600 (0.444 sec)
# INFO:tensorflow:global_step/sec: 233.277
# INFO:tensorflow:loss = 1129.2446, step = 2700 (0.426 sec)
# INFO:tensorflow:global_step/sec: 236.624
# INFO:tensorflow:loss = 1121.4784, step = 2800 (0.423 sec)
# INFO:tensorflow:global_step/sec: 237.676
# INFO:tensorflow:loss = 1069.4738, step = 2900 (0.422 sec)
# INFO:tensorflow:global_step/sec: 239.736
# INFO:tensorflow:loss = 1090.1973, step = 3000 (0.417 sec)
# INFO:tensorflow:global_step/sec: 268.469
# INFO:tensorflow:loss = 1071.6687, step = 3100 (0.372 sec)
# INFO:tensorflow:global_step/sec: 291.008
# INFO:tensorflow:loss = 1059.7675, step = 3200 (0.345 sec)
# INFO:tensorflow:global_step/sec: 306.354
# INFO:tensorflow:loss = 1049.6788, step = 3300 (0.325 sec)
# INFO:tensorflow:global_step/sec: 307.894
# INFO:tensorflow:loss = 1059.7258, step = 3400 (0.325 sec)
# INFO:tensorflow:global_step/sec: 308.987
# INFO:tensorflow:loss = 997.63965, step = 3500 (0.323 sec)
# INFO:tensorflow:global_step/sec: 311.714
# INFO:tensorflow:loss = 1011.13666, step = 3600 (0.321 sec)
# INFO:tensorflow:global_step/sec: 302.163
# INFO:tensorflow:loss = 1000.1898, step = 3700 (0.334 sec)
# INFO:tensorflow:global_step/sec: 297.189
# INFO:tensorflow:loss = 1088.1648, step = 3800 (0.336 sec)
# INFO:tensorflow:global_step/sec: 292.949
# INFO:tensorflow:loss = 998.91, step = 3900 (0.340 sec)
# INFO:tensorflow:global_step/sec: 290.474
# INFO:tensorflow:loss = 992.79736, step = 4000 (0.345 sec)
# INFO:tensorflow:global_step/sec: 298.805
# INFO:tensorflow:loss = 897.68207, step = 4100 (0.335 sec)
# INFO:tensorflow:global_step/sec: 282.223
# INFO:tensorflow:loss = 938.8969, step = 4200 (0.354 sec)
# INFO:tensorflow:global_step/sec: 290.298
# INFO:tensorflow:loss = 924.9182, step = 4300 (0.346 sec)
# INFO:tensorflow:global_step/sec: 263.531
# INFO:tensorflow:loss = 865.07947, step = 4400 (0.379 sec)
# INFO:tensorflow:global_step/sec: 270.575
# INFO:tensorflow:loss = 924.31116, step = 4500 (0.369 sec)
# INFO:tensorflow:global_step/sec: 268.637
# INFO:tensorflow:loss = 894.6639, step = 4600 (0.372 sec)
# INFO:tensorflow:global_step/sec: 265.829
# INFO:tensorflow:loss = 872.739, step = 4700 (0.378 sec)
# INFO:tensorflow:global_step/sec: 268.269
# INFO:tensorflow:loss = 904.52606, step = 4800 (0.371 sec)
# INFO:tensorflow:global_step/sec: 279.9
# INFO:tensorflow:loss = 927.1473, step = 4900 (0.357 sec)
# INFO:tensorflow:global_step/sec: 274.655
# INFO:tensorflow:loss = 896.4113, step = 5000 (0.364 sec)
# INFO:tensorflow:global_step/sec: 285.617
# INFO:tensorflow:loss = 901.65137, step = 5100 (0.351 sec)
# INFO:tensorflow:global_step/sec: 293.19
# INFO:tensorflow:loss = 892.7442, step = 5200 (0.340 sec)
# INFO:tensorflow:global_step/sec: 287.251
# INFO:tensorflow:loss = 850.54987, step = 5300 (0.348 sec)
# INFO:tensorflow:global_step/sec: 290.859
# INFO:tensorflow:loss = 843.34564, step = 5400 (0.343 sec)
# INFO:tensorflow:global_step/sec: 285.349
# INFO:tensorflow:loss = 842.5176, step = 5500 (0.351 sec)
# INFO:tensorflow:global_step/sec: 298.838
# INFO:tensorflow:loss = 783.9348, step = 5600 (0.334 sec)
# INFO:tensorflow:global_step/sec: 293.904
# INFO:tensorflow:loss = 847.24524, step = 5700 (0.340 sec)
# INFO:tensorflow:global_step/sec: 298.333
# INFO:tensorflow:loss = 766.3622, step = 5800 (0.335 sec)
# INFO:tensorflow:global_step/sec: 293.503
# INFO:tensorflow:loss = 765.00055, step = 5900 (0.341 sec)
# INFO:tensorflow:global_step/sec: 286.416
# INFO:tensorflow:loss = 810.5467, step = 6000 (0.351 sec)
# INFO:tensorflow:global_step/sec: 295.384
# INFO:tensorflow:loss = 827.7368, step = 6100 (0.337 sec)
# INFO:tensorflow:global_step/sec: 273.261
# INFO:tensorflow:loss = 740.6531, step = 6200 (0.366 sec)
# INFO:tensorflow:global_step/sec: 290.096
# INFO:tensorflow:loss = 758.3251, step = 6300 (0.345 sec)
# INFO:tensorflow:global_step/sec: 278.708
# INFO:tensorflow:loss = 791.2857, step = 6400 (0.359 sec)
# INFO:tensorflow:global_step/sec: 284.851
# INFO:tensorflow:loss = 726.38513, step = 6500 (0.352 sec)
# INFO:tensorflow:global_step/sec: 318.852
# INFO:tensorflow:loss = 670.99414, step = 6600 (0.313 sec)
# INFO:tensorflow:global_step/sec: 286.428
# INFO:tensorflow:loss = 731.8678, step = 6700 (0.349 sec)
# INFO:tensorflow:global_step/sec: 271.637
# INFO:tensorflow:loss = 802.6353, step = 6800 (0.368 sec)
# INFO:tensorflow:global_step/sec: 275.899
# INFO:tensorflow:loss = 683.4132, step = 6900 (0.363 sec)
# INFO:tensorflow:global_step/sec: 265.25
# INFO:tensorflow:loss = 710.717, step = 7000 (0.378 sec)
# INFO:tensorflow:global_step/sec: 249.633
# INFO:tensorflow:loss = 685.51044, step = 7100 (0.400 sec)
# INFO:tensorflow:global_step/sec: 254.543
# INFO:tensorflow:loss = 734.6647, step = 7200 (0.393 sec)
# INFO:tensorflow:global_step/sec: 250.511
# INFO:tensorflow:loss = 800.9431, step = 7300 (0.399 sec)
# INFO:tensorflow:global_step/sec: 267.003
# INFO:tensorflow:loss = 684.3728, step = 7400 (0.376 sec)
# INFO:tensorflow:global_step/sec: 237.255
# INFO:tensorflow:loss = 670.3523, step = 7500 (0.421 sec)
# INFO:tensorflow:global_step/sec: 264.687
# INFO:tensorflow:loss = 669.5657, step = 7600 (0.378 sec)
# INFO:tensorflow:global_step/sec: 267.375
# INFO:tensorflow:loss = 651.1532, step = 7700 (0.374 sec)
# INFO:tensorflow:global_step/sec: 262.4
# INFO:tensorflow:loss = 689.55365, step = 7800 (0.381 sec)
# INFO:tensorflow:global_step/sec: 246.181
# INFO:tensorflow:loss = 215.29381, step = 7900 (0.408 sec)
# INFO:tensorflow:global_step/sec: 284.125
# INFO:tensorflow:loss = 255.80269, step = 8000 (0.351 sec)
# INFO:tensorflow:global_step/sec: 272.923
# INFO:tensorflow:loss = 255.47714, step = 8100 (0.366 sec)
# INFO:tensorflow:global_step/sec: 272.202
# INFO:tensorflow:loss = 313.4738, step = 8200 (0.367 sec)
# INFO:tensorflow:global_step/sec: 294.454
# INFO:tensorflow:loss = 341.56854, step = 8300 (0.339 sec)
# INFO:tensorflow:global_step/sec: 276.753
# INFO:tensorflow:loss = 345.54614, step = 8400 (0.361 sec)
# INFO:tensorflow:global_step/sec: 268.447
# INFO:tensorflow:loss = 308.86856, step = 8500 (0.374 sec)
# INFO:tensorflow:global_step/sec: 251.663
# INFO:tensorflow:loss = 310.78094, step = 8600 (0.396 sec)
# INFO:tensorflow:global_step/sec: 253.099
# INFO:tensorflow:loss = 376.49774, step = 8700 (0.395 sec)
# INFO:tensorflow:global_step/sec: 272.493
# INFO:tensorflow:loss = 371.20367, step = 8800 (0.367 sec)
# INFO:tensorflow:global_step/sec: 270.611
# INFO:tensorflow:loss = 397.55606, step = 8900 (0.370 sec)
# INFO:tensorflow:global_step/sec: 265.068
# INFO:tensorflow:loss = 376.9532, step = 9000 (0.377 sec)
# INFO:tensorflow:global_step/sec: 275.368
# INFO:tensorflow:loss = 411.6964, step = 9100 (0.363 sec)
# INFO:tensorflow:global_step/sec: 275.283
# INFO:tensorflow:loss = 365.7428, step = 9200 (0.363 sec)
# INFO:tensorflow:global_step/sec: 297.735
# INFO:tensorflow:loss = 400.64224, step = 9300 (0.336 sec)
# INFO:tensorflow:global_step/sec: 305.401
# INFO:tensorflow:loss = 415.9427, step = 9400 (0.327 sec)
# INFO:tensorflow:global_step/sec: 300.101
# INFO:tensorflow:loss = 384.34558, step = 9500 (0.334 sec)
# INFO:tensorflow:global_step/sec: 279.76
# INFO:tensorflow:loss = 441.595, step = 9600 (0.357 sec)
# INFO:tensorflow:global_step/sec: 270.633
# INFO:tensorflow:loss = 412.03503, step = 9700 (0.369 sec)
# INFO:tensorflow:global_step/sec: 276.883
# INFO:tensorflow:loss = 443.11517, step = 9800 (0.361 sec)
# INFO:tensorflow:global_step/sec: 304.013
# INFO:tensorflow:loss = 373.2499, step = 9900 (0.329 sec)
# INFO:tensorflow:global_step/sec: 294.394
# INFO:tensorflow:loss = 421.726, step = 10000 (0.339 sec)
# INFO:tensorflow:global_step/sec: 270.681
# INFO:tensorflow:loss = 445.08557, step = 10100 (0.370 sec)
# INFO:tensorflow:global_step/sec: 279.541
# INFO:tensorflow:loss = 430.2792, step = 10200 (0.357 sec)
# INFO:tensorflow:global_step/sec: 283.382
# INFO:tensorflow:loss = 426.40793, step = 10300 (0.353 sec)
# INFO:tensorflow:global_step/sec: 284.9
# INFO:tensorflow:loss = 474.53366, step = 10400 (0.351 sec)
# INFO:tensorflow:global_step/sec: 259.344
# INFO:tensorflow:loss = 445.18204, step = 10500 (0.386 sec)
# INFO:tensorflow:global_step/sec: 250.104
# INFO:tensorflow:loss = 421.61127, step = 10600 (0.401 sec)
# INFO:tensorflow:global_step/sec: 242.772
# INFO:tensorflow:loss = 428.8924, step = 10700 (0.411 sec)
# INFO:tensorflow:global_step/sec: 258.616
# INFO:tensorflow:loss = 491.2233, step = 10800 (0.387 sec)
# INFO:tensorflow:global_step/sec: 273.623
# INFO:tensorflow:loss = 455.58322, step = 10900 (0.365 sec)
# INFO:tensorflow:global_step/sec: 267.212
# INFO:tensorflow:loss = 485.18387, step = 11000 (0.374 sec)
# INFO:tensorflow:global_step/sec: 253.478
# INFO:tensorflow:loss = 447.16315, step = 11100 (0.395 sec)
# INFO:tensorflow:global_step/sec: 240.525
# INFO:tensorflow:loss = 428.04965, step = 11200 (0.417 sec)
# INFO:tensorflow:global_step/sec: 243.412
# INFO:tensorflow:loss = 456.9877, step = 11300 (0.410 sec)
# INFO:tensorflow:global_step/sec: 239.46
# INFO:tensorflow:loss = 449.60406, step = 11400 (0.417 sec)
# INFO:tensorflow:global_step/sec: 245.472
# INFO:tensorflow:loss = 477.90903, step = 11500 (0.407 sec)
# INFO:tensorflow:global_step/sec: 255.359
# INFO:tensorflow:loss = 473.26547, step = 11600 (0.393 sec)
# INFO:tensorflow:global_step/sec: 261.208
# INFO:tensorflow:loss = 462.49942, step = 11700 (0.382 sec)
# INFO:tensorflow:global_step/sec: 281.04
# INFO:tensorflow:loss = 439.44635, step = 11800 (0.356 sec)
# INFO:tensorflow:global_step/sec: 280.846
# INFO:tensorflow:loss = 456.3284, step = 11900 (0.355 sec)
# INFO:tensorflow:global_step/sec: 269.84
# INFO:tensorflow:loss = 446.49783, step = 12000 (0.371 sec)
# INFO:tensorflow:global_step/sec: 260.863
# INFO:tensorflow:loss = 511.33313, step = 12100 (0.383 sec)
# INFO:tensorflow:global_step/sec: 247.255
# INFO:tensorflow:loss = 471.68274, step = 12200 (0.406 sec)
# INFO:tensorflow:global_step/sec: 267.009
# INFO:tensorflow:loss = 453.0332, step = 12300 (0.373 sec)
# INFO:tensorflow:global_step/sec: 264.794
# INFO:tensorflow:loss = 448.7835, step = 12400 (0.378 sec)
# INFO:tensorflow:global_step/sec: 296.925
# INFO:tensorflow:loss = 466.60553, step = 12500 (0.339 sec)
# INFO:tensorflow:global_step/sec: 294.254
# INFO:tensorflow:loss = 435.78006, step = 12600 (0.339 sec)
# INFO:tensorflow:global_step/sec: 284.3
# INFO:tensorflow:loss = 469.10757, step = 12700 (0.351 sec)
# INFO:tensorflow:global_step/sec: 296.869
# INFO:tensorflow:loss = 469.70255, step = 12800 (0.337 sec)
# INFO:tensorflow:global_step/sec: 278.997
# INFO:tensorflow:loss = 485.26648, step = 12900 (0.358 sec)
# INFO:tensorflow:global_step/sec: 281.377
# INFO:tensorflow:loss = 435.17456, step = 13000 (0.355 sec)
# INFO:tensorflow:global_step/sec: 295.571
# INFO:tensorflow:loss = 415.96887, step = 13100 (0.338 sec)
# INFO:tensorflow:global_step/sec: 268.882
# INFO:tensorflow:loss = 493.2399, step = 13200 (0.373 sec)
# INFO:tensorflow:global_step/sec: 230.907
# INFO:tensorflow:loss = 425.4519, step = 13300 (0.433 sec)
# INFO:tensorflow:global_step/sec: 218.629
# INFO:tensorflow:loss = 428.0005, step = 13400 (0.457 sec)
# INFO:tensorflow:global_step/sec: 225.02
# INFO:tensorflow:loss = 444.4456, step = 13500 (0.446 sec)
# INFO:tensorflow:global_step/sec: 243.207
# INFO:tensorflow:loss = 439.67288, step = 13600 (0.410 sec)
# INFO:tensorflow:global_step/sec: 245.444
# INFO:tensorflow:loss = 476.54144, step = 13700 (0.408 sec)
# INFO:tensorflow:global_step/sec: 256.901
# INFO:tensorflow:loss = 395.89655, step = 13800 (0.389 sec)
# INFO:tensorflow:global_step/sec: 260.284
# INFO:tensorflow:loss = 482.3792, step = 13900 (0.383 sec)
# INFO:tensorflow:global_step/sec: 263.042
# INFO:tensorflow:loss = 455.20038, step = 14000 (0.383 sec)
# INFO:tensorflow:global_step/sec: 262.183
# INFO:tensorflow:loss = 418.6556, step = 14100 (0.380 sec)
# INFO:tensorflow:global_step/sec: 266.308
# INFO:tensorflow:loss = 453.5155, step = 14200 (0.376 sec)
# INFO:tensorflow:global_step/sec: 261.458
# INFO:tensorflow:loss = 498.56662, step = 14300 (0.382 sec)
# INFO:tensorflow:global_step/sec: 259.53
# INFO:tensorflow:loss = 474.6867, step = 14400 (0.386 sec)
# INFO:tensorflow:global_step/sec: 266.553
# INFO:tensorflow:loss = 455.24182, step = 14500 (0.377 sec)
# INFO:tensorflow:global_step/sec: 268.673
# INFO:tensorflow:loss = 470.38345, step = 14600 (0.370 sec)
# INFO:tensorflow:global_step/sec: 273.725
# INFO:tensorflow:loss = 454.30542, step = 14700 (0.365 sec)
# INFO:tensorflow:global_step/sec: 252.842
# INFO:tensorflow:loss = 483.2635, step = 14800 (0.395 sec)
# INFO:tensorflow:global_step/sec: 251.7
# INFO:tensorflow:loss = 445.7732, step = 14900 (0.398 sec)
# INFO:tensorflow:global_step/sec: 244.959
# INFO:tensorflow:loss = 486.2284, step = 15000 (0.408 sec)
# INFO:tensorflow:global_step/sec: 251.405
# INFO:tensorflow:loss = 432.7016, step = 15100 (0.398 sec)
# INFO:tensorflow:global_step/sec: 220.84
# INFO:tensorflow:loss = 463.96942, step = 15200 (0.452 sec)
# INFO:tensorflow:global_step/sec: 225.772
# INFO:tensorflow:loss = 440.37936, step = 15300 (0.444 sec)
# INFO:tensorflow:global_step/sec: 233.183
# INFO:tensorflow:loss = 402.13898, step = 15400 (0.429 sec)
# INFO:tensorflow:global_step/sec: 223.717
# INFO:tensorflow:loss = 484.21667, step = 15500 (0.448 sec)
# INFO:tensorflow:global_step/sec: 237.259
# INFO:tensorflow:loss = 403.63083, step = 15600 (0.420 sec)
# INFO:tensorflow:global_step/sec: 237.68
# INFO:tensorflow:loss = 232.2701, step = 15700 (0.421 sec)
# INFO:tensorflow:global_step/sec: 254.531
# INFO:tensorflow:loss = 230.08563, step = 15800 (0.392 sec)
# INFO:tensorflow:global_step/sec: 260.598
# INFO:tensorflow:loss = 262.54135, step = 15900 (0.384 sec)
# INFO:tensorflow:global_step/sec: 257.023
# INFO:tensorflow:loss = 255.00323, step = 16000 (0.389 sec)
# INFO:tensorflow:global_step/sec: 275.554
# INFO:tensorflow:loss = 261.2352, step = 16100 (0.364 sec)
# INFO:tensorflow:global_step/sec: 262.979
# INFO:tensorflow:loss = 268.5995, step = 16200 (0.379 sec)
# INFO:tensorflow:global_step/sec: 263.658
# INFO:tensorflow:loss = 305.18988, step = 16300 (0.379 sec)
# INFO:tensorflow:global_step/sec: 290.306
# INFO:tensorflow:loss = 285.44427, step = 16400 (0.344 sec)
# INFO:tensorflow:global_step/sec: 297.115
# INFO:tensorflow:loss = 304.76093, step = 16500 (0.337 sec)
# INFO:tensorflow:global_step/sec: 294.454
# INFO:tensorflow:loss = 275.39624, step = 16600 (0.340 sec)
# INFO:tensorflow:global_step/sec: 273.103
# INFO:tensorflow:loss = 327.1466, step = 16700 (0.366 sec)
# INFO:tensorflow:global_step/sec: 258.529
# INFO:tensorflow:loss = 328.8109, step = 16800 (0.387 sec)
# INFO:tensorflow:global_step/sec: 257.386
# INFO:tensorflow:loss = 300.5881, step = 16900 (0.389 sec)
# INFO:tensorflow:global_step/sec: 254.622
# INFO:tensorflow:loss = 309.00455, step = 17000 (0.392 sec)
# INFO:tensorflow:global_step/sec: 267.362
# INFO:tensorflow:loss = 300.48355, step = 17100 (0.374 sec)
# INFO:tensorflow:global_step/sec: 266.431
# INFO:tensorflow:loss = 321.50925, step = 17200 (0.375 sec)
# INFO:tensorflow:global_step/sec: 277.337
# INFO:tensorflow:loss = 294.1383, step = 17300 (0.361 sec)
# INFO:tensorflow:global_step/sec: 266.906
# INFO:tensorflow:loss = 353.66803, step = 17400 (0.375 sec)
# INFO:tensorflow:global_step/sec: 244.96
# INFO:tensorflow:loss = 279.99072, step = 17500 (0.408 sec)
# INFO:tensorflow:global_step/sec: 252.397
# INFO:tensorflow:loss = 318.02017, step = 17600 (0.396 sec)
# INFO:tensorflow:global_step/sec: 266.122
# INFO:tensorflow:loss = 314.74026, step = 17700 (0.376 sec)
# INFO:tensorflow:global_step/sec: 276.669
# INFO:tensorflow:loss = 310.23096, step = 17800 (0.361 sec)
# INFO:tensorflow:global_step/sec: 274.304
# INFO:tensorflow:loss = 335.21686, step = 17900 (0.365 sec)
# INFO:tensorflow:global_step/sec: 240.669
# INFO:tensorflow:loss = 317.52036, step = 18000 (0.417 sec)
# INFO:tensorflow:global_step/sec: 233.963
# INFO:tensorflow:loss = 302.3679, step = 18100 (0.426 sec)
# INFO:tensorflow:global_step/sec: 244.609
# INFO:tensorflow:loss = 341.52185, step = 18200 (0.409 sec)
# INFO:tensorflow:global_step/sec: 251.739
# INFO:tensorflow:loss = 343.56183, step = 18300 (0.398 sec)
# INFO:tensorflow:global_step/sec: 241.383
# INFO:tensorflow:loss = 379.8909, step = 18400 (0.413 sec)
# INFO:tensorflow:global_step/sec: 231.4
# INFO:tensorflow:loss = 346.82428, step = 18500 (0.432 sec)
# INFO:tensorflow:global_step/sec: 241.885
# INFO:tensorflow:loss = 355.3022, step = 18600 (0.414 sec)
# INFO:tensorflow:global_step/sec: 280.219
# INFO:tensorflow:loss = 324.43683, step = 18700 (0.357 sec)
# INFO:tensorflow:global_step/sec: 249.227
# INFO:tensorflow:loss = 360.96982, step = 18800 (0.403 sec)
# INFO:tensorflow:global_step/sec: 246.364
# INFO:tensorflow:loss = 327.0832, step = 18900 (0.405 sec)
# INFO:tensorflow:global_step/sec: 240.894
# INFO:tensorflow:loss = 344.0832, step = 19000 (0.415 sec)
# INFO:tensorflow:global_step/sec: 246.301
# INFO:tensorflow:loss = 367.80615, step = 19100 (0.409 sec)
# INFO:tensorflow:global_step/sec: 252.266
# INFO:tensorflow:loss = 359.4579, step = 19200 (0.394 sec)
# INFO:tensorflow:global_step/sec: 255.029
# INFO:tensorflow:loss = 355.0482, step = 19300 (0.391 sec)
# INFO:tensorflow:global_step/sec: 261.501
# INFO:tensorflow:loss = 313.64575, step = 19400 (0.382 sec)
# INFO:tensorflow:global_step/sec: 237.685
# INFO:tensorflow:loss = 374.8467, step = 19500 (0.421 sec)
# INFO:tensorflow:global_step/sec: 233.097
# INFO:tensorflow:loss = 342.70312, step = 19600 (0.429 sec)
# INFO:tensorflow:global_step/sec: 260.301
# INFO:tensorflow:loss = 347.1849, step = 19700 (0.384 sec)
# INFO:tensorflow:global_step/sec: 262.016
# INFO:tensorflow:loss = 330.154, step = 19800 (0.383 sec)
# INFO:tensorflow:global_step/sec: 256.217
# INFO:tensorflow:loss = 347.41452, step = 19900 (0.389 sec)
# INFO:tensorflow:global_step/sec: 263.286
# INFO:tensorflow:loss = 370.94815, step = 20000 (0.380 sec)
# INFO:tensorflow:global_step/sec: 264.437
# INFO:tensorflow:loss = 363.8869, step = 20100 (0.378 sec)
# INFO:tensorflow:global_step/sec: 256.987
# INFO:tensorflow:loss = 357.11694, step = 20200 (0.389 sec)
# INFO:tensorflow:global_step/sec: 229.213
# INFO:tensorflow:loss = 324.96472, step = 20300 (0.439 sec)
# INFO:tensorflow:global_step/sec: 271.434
# INFO:tensorflow:loss = 378.81793, step = 20400 (0.365 sec)
# INFO:tensorflow:global_step/sec: 280.316
# INFO:tensorflow:loss = 315.43988, step = 20500 (0.356 sec)
# INFO:tensorflow:global_step/sec: 282.267
# INFO:tensorflow:loss = 393.28018, step = 20600 (0.355 sec)
# INFO:tensorflow:global_step/sec: 257.712
# INFO:tensorflow:loss = 343.27853, step = 20700 (0.389 sec)
# INFO:tensorflow:global_step/sec: 267.135
# INFO:tensorflow:loss = 344.5199, step = 20800 (0.374 sec)
# INFO:tensorflow:global_step/sec: 266.948
# INFO:tensorflow:loss = 339.63144, step = 20900 (0.374 sec)
# INFO:tensorflow:global_step/sec: 253.337
# INFO:tensorflow:loss = 366.99655, step = 21000 (0.395 sec)
# INFO:tensorflow:global_step/sec: 243.126
# INFO:tensorflow:loss = 343.1393, step = 21100 (0.411 sec)
# INFO:tensorflow:global_step/sec: 251.195
# INFO:tensorflow:loss = 342.42993, step = 21200 (0.398 sec)
# INFO:tensorflow:global_step/sec: 258.512
# INFO:tensorflow:loss = 363.39047, step = 21300 (0.387 sec)
# INFO:tensorflow:global_step/sec: 254.44
# INFO:tensorflow:loss = 364.54376, step = 21400 (0.395 sec)
# INFO:tensorflow:global_step/sec: 282.513
# INFO:tensorflow:loss = 394.51642, step = 21500 (0.353 sec)
# INFO:tensorflow:global_step/sec: 285.827
# INFO:tensorflow:loss = 341.89514, step = 21600 (0.349 sec)
# INFO:tensorflow:global_step/sec: 274.493
# INFO:tensorflow:loss = 378.35538, step = 21700 (0.364 sec)
# INFO:tensorflow:global_step/sec: 298.595
# INFO:tensorflow:loss = 361.08234, step = 21800 (0.336 sec)
# INFO:tensorflow:global_step/sec: 317.296
# INFO:tensorflow:loss = 357.31, step = 21900 (0.314 sec)
# INFO:tensorflow:global_step/sec: 301.616
# INFO:tensorflow:loss = 386.78326, step = 22000 (0.331 sec)
# INFO:tensorflow:global_step/sec: 293.322
# INFO:tensorflow:loss = 350.789, step = 22100 (0.341 sec)
# INFO:tensorflow:global_step/sec: 302.688
# INFO:tensorflow:loss = 373.12048, step = 22200 (0.331 sec)
# INFO:tensorflow:global_step/sec: 296.652
# INFO:tensorflow:loss = 345.5563, step = 22300 (0.337 sec)
# INFO:tensorflow:global_step/sec: 289.631
# INFO:tensorflow:loss = 369.32153, step = 22400 (0.345 sec)
# INFO:tensorflow:global_step/sec: 293.057
# INFO:tensorflow:loss = 372.08008, step = 22500 (0.342 sec)
# INFO:tensorflow:global_step/sec: 288.648
# INFO:tensorflow:loss = 382.00903, step = 22600 (0.346 sec)
# INFO:tensorflow:global_step/sec: 251.678
# INFO:tensorflow:loss = 360.06403, step = 22700 (0.397 sec)
# INFO:tensorflow:global_step/sec: 257.741
# INFO:tensorflow:loss = 368.30066, step = 22800 (0.388 sec)
# INFO:tensorflow:global_step/sec: 248.042
# INFO:tensorflow:loss = 360.1273, step = 22900 (0.403 sec)
# INFO:tensorflow:global_step/sec: 274.331
# INFO:tensorflow:loss = 367.11575, step = 23000 (0.364 sec)
# INFO:tensorflow:global_step/sec: 257.286
# INFO:tensorflow:loss = 345.5844, step = 23100 (0.388 sec)
# INFO:tensorflow:global_step/sec: 254.233
# INFO:tensorflow:loss = 367.65897, step = 23200 (0.394 sec)
# INFO:tensorflow:global_step/sec: 249.937
# INFO:tensorflow:loss = 374.214, step = 23300 (0.400 sec)
# INFO:tensorflow:global_step/sec: 279.745
# INFO:tensorflow:loss = 363.58585, step = 23400 (0.358 sec)
# INFO:tensorflow:Saving checkpoints for 23439 into /tmp/tmpevc_odlj/model.ckpt.
# INFO:tensorflow:Loss for final step: 129.16873.

# %% [markdown]
# ## Retrieval

# %% [markdown]
# ### Export embeddings
#
# After the retrieval model is trained, we need to export all the query and item embeddings with the trained parameters. With Tensorflow Estimator framework, this can be done easily by constructing another *input_fn* to feed all the data to the model and grab the predictions once.

# %%
def predict_input_fn():
    dataset = tf.data.Dataset.from_tensor_slices({'query': np.arange(VOCAB_SIZE), 'item': np.arange(VOCAB_SIZE)})
    dataset = dataset.batch(VOCAB_SIZE)
    return dataset

results = list(retrieval_model.predict(input_fn=predict_input_fn))
query_emb = np.stack([r['query'] for r in results], axis=0)
item_emb = np.stack([r['item'] for r in results], axis=0)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpevc_odlj/model.ckpt-23439
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# ### Brute force search
#
# Before we try approximate nearest neighbor (ANN) search algorithms, let's first do a brute force search to get the upper bound of the retrieval accuracy. Theoretically, any ANN search algorithms should be much faster than Brute Force method but somewhat worse in retrieval accuracy.

# %%
def brute_force_search(query_id, items, k=10):
    query = query_emb[query_id:(query_id+1), :]
    query_norm = np.linalg.norm(query, axis=1, keepdims=True)
    item_norm = np.linalg.norm(items, axis=1, keepdims=True)
    cos = np.matmul(query, np.transpose(items)) / query_norm / np.transpose(item_norm)
    cos = cos.flatten()
    sorted_item_id = np.argsort(-cos)
    return sorted_item_id[:k]

# %% [markdown]
# Let's have quick look at the retrieval results. Note that the retrieved item IDs all have the two digits, 8 and 9.

# %%
brute_force_search(98, item_emb)
# Out:
# array([9998, 1998, 8179, 1698, 1978, 3981, 8964, 6948, 7789, 8901])

# %% [markdown]
# Now we can compute a comprehensive retrieval accuracy called precision@k, where we use k=100. This metric measures that for the top 100 retrieved items, how much percentage of them are correct.

# %%
def precision_at_k(search_fn, query_id, items, k=100):
    nn_items = search_fn(query_id, items, k=k)
    
    d, c, b, a = nn_items % 10, (nn_items // 10) % 10, (nn_items // 100) % 10, (nn_items // 1000) % 10
    abcd = np.stack([a, b, c, d], axis=1)
    y, x = query_id % 10, (query_id // 10) % 10
    # check if x and y can be drawn from abcd without replacement
    match = np.sum(np.logical_or(x == abcd, y == abcd), axis=1) >= 2 
    precision = np.sum(match) / k
    return precision

precision_at_100 = [precision_at_k(brute_force_search, i, item_emb, k=100) for i in range(VOCAB_SIZE)]
print("overall precision@100 = ", np.mean(precision_at_100))
# Out:
# overall precision@100 =  0.998862

# %% [markdown]
# ## Faiss search

# %% [markdown]
# Now let's try Faiss, which is a widely used ANN library developed by Facebook. It is based on Product Quantization techniques. Here we set our index type to be 'IVF8,PQ8', which means coarse quantization into *8* clusters and then product quantization into *8* segments, each of which is represented by *one* byte, or *2^8 = 256* subvectors.
#
# First, we need to build an embedding index with all the item embeddings. Note that we need to first normalize all item embeddings before building the index with *inner product* as distance metric, or more precisely, inverse distance metric.

# %%
import faiss

index = faiss.index_factory(EMB_DIM, 'IVF8,PQ8', faiss.METRIC_INNER_PRODUCT)
item_emb = item_emb / np.linalg.norm(item_emb, axis=1, keepdims=True)
index.train(item_emb)
index.add(item_emb)
# Out:
# Loading faiss with AVX2 support.
# Loading faiss.

# %%
def faiss_search(query_id, items, k=10):
    query = query_emb[query_id:(query_id+1), :]
    D, I = index.search(query, k)
    D, I = D.flatten(), I.flatten()
    return I[:k]

# %%
precision_at_100 = [precision_at_k(faiss_search, i, item_emb, k=100) for i in range(VOCAB_SIZE)]
print("overall precision@100 = ", np.mean(precision_at_100))
# Out:
# overall precision@100 =  0.960966

# %% [markdown]
# ## Poeem search

# %% [markdown]
# Apart from above separately built embedding index, *poeem* learns the embedding model jointly with embedding index. Thus, there is no extra index building step. But we need to make some simple changes into the above *model_fn* function to adopt *poeem* indexing layer.
#
# Note that we only need to make changes at three places, marked by ### [poeem code]

# %%
def poeem_model_fn(features, labels, mode, params):
    query_column = tf.feature_column.embedding_column(
        tf.feature_column.categorical_column_with_vocabulary_list(
            key='query',
            vocabulary_list=range(VOCAB_SIZE),
            dtype=tf.int32),
        dimension=EMB_DIM)
    query_emb = tf.feature_column.input_layer(features, [query_column])
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        ### [poeem code] directly do ANN search in the model as a TensorFlow op.
        if params.get('item_search', False):
            index = poeem.search.index_from_file(params['index_file'])
            neighbors, scores = index.search(
                tf.expand_dims(query_emb, 1),
                params['topk'],
                params['nprobe'],
                params['metric_type'],
                verbose=False)        
            return tf.estimator.EstimatorSpec(
                mode, predictions={'neighbors': neighbors, 'scores': scores})
        ### end [poeem code]
        
    item_column = tf.feature_column.embedding_column(
        tf.feature_column.categorical_column_with_vocabulary_list(
            key='item',
            vocabulary_list=range(VOCAB_SIZE),
            dtype=tf.int32),
        dimension=EMB_DIM)
    item_emb = tf.feature_column.input_layer(features, [item_column])
    item_emb = tf.nn.l2_normalize(item_emb, axis=1)
    

    ### [poeem code] item indexing layer as the last layer in item tower
    hparams = poeem.embedding.PoeemHparam(coarse_K=8,
                                          K=256,
                                          D=8,
                                          rotate=0) # exactly the same parameters as Faiss, specified above.
    item_batch_quantized = poeem.embedding.PoeemEmbed(
        EMB_DIM,
        warmup_steps=16384,
        buffer_size=8192,
        hparams=hparams,
        mode=mode)
    
    # gradient straight-through estimator. For details, check out our paper.
    item_emb_tau, coarse_code, code, regularizer = item_batch_quantized.forward(item_emb)
    item_emb = item_emb - tf.stop_gradient(item_emb - item_emb_tau)
    ### end [poeem code] 

    if mode == tf.estimator.ModeKeys.PREDICT:
        ### [poeem code] exprt item embeddings/PQ code for disk persistency.
        if params.get('item_predict', False):
            return tf.estimator.EstimatorSpec(
                mode, predictions={
                    'item_coarse_code': coarse_code,
                    'item_code': code,
                    'item_norm': tf.norm(item_emb, axis=1)
                })
        ### end [poeem code] 

    def cosine(a, b):
        a = tf.nn.l2_normalize(a, axis=1)
        b = tf.nn.l2_normalize(b, axis=1)
        return tf.matmul(a, b, transpose_b=True)

    scores = cosine(query_emb, item_emb)

    batch_size = tf.shape(query_emb)[0]
    loss = tf.reduce_sum(
        tf.nn.softmax_cross_entropy_with_logits_v2(
            labels=tf.eye(batch_size),
            logits=scores * 30))
    
    loss = loss + regularizer

    optimizer = tf.train.AdagradOptimizer(LEARNING_RATE)
    train_op = optimizer.minimize(loss, global_step=tf.train.get_global_step())

    return tf.estimator.EstimatorSpec(
        mode, loss=loss, train_op=train_op, predictions={'query': query_emb, 'item': item_emb})

# %%
MODEL_DIR = './poeem_model'
poeem_model = tf.estimator.Estimator(model_fn=poeem_model_fn, model_dir=MODEL_DIR, params={})
poeem_model.train(input_fn=input_fn)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './poeem_model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5836487eb8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/poeem/python/embedding.py:71: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/poeem/python/embedding.py:249: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/poeem/python/embedding.py:100: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/poeem/python/embedding.py:338: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/poeem/python/embedding.py:344: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/poeem/python/embedding.py:348: The name tf.scatter_add is deprecated. Please use tf.compat.v1.scatter_add instead.
#
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/poeem/python/embedding.py:348: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/poeem/python/embedding.py:349: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./poeem_model/model.ckpt.
# INFO:tensorflow:loss = 1341.468, step = 0
# INFO:tensorflow:global_step/sec: 121.023
# INFO:tensorflow:loss = 1240.985, step = 100 (0.827 sec)
# INFO:tensorflow:global_step/sec: 189.952
# INFO:tensorflow:loss = 1325.3485, step = 200 (0.526 sec)
# INFO:tensorflow:global_step/sec: 192.579
# INFO:tensorflow:loss = 1352.7329, step = 300 (0.519 sec)
# INFO:tensorflow:global_step/sec: 192.313
# INFO:tensorflow:loss = 1361.7343, step = 400 (0.520 sec)
# INFO:tensorflow:global_step/sec: 211.73
# INFO:tensorflow:loss = 1352.4163, step = 500 (0.472 sec)
# INFO:tensorflow:global_step/sec: 226.827
# INFO:tensorflow:loss = 1251.8898, step = 600 (0.443 sec)
# INFO:tensorflow:global_step/sec: 229.241
# INFO:tensorflow:loss = 1294.7876, step = 700 (0.434 sec)
# INFO:tensorflow:global_step/sec: 231.556
# INFO:tensorflow:loss = 1324.322, step = 800 (0.432 sec)
# INFO:tensorflow:global_step/sec: 229.407
# INFO:tensorflow:loss = 1385.8263, step = 900 (0.437 sec)
# INFO:tensorflow:global_step/sec: 232.337
# INFO:tensorflow:loss = 1263.7744, step = 1000 (0.429 sec)
# INFO:tensorflow:global_step/sec: 238.041
# INFO:tensorflow:loss = 1333.9688, step = 1100 (0.420 sec)
# INFO:tensorflow:global_step/sec: 236.887
# INFO:tensorflow:loss = 1262.647, step = 1200 (0.424 sec)
# INFO:tensorflow:global_step/sec: 228.873
# INFO:tensorflow:loss = 1245.8507, step = 1300 (0.436 sec)
# INFO:tensorflow:global_step/sec: 227.733
# INFO:tensorflow:loss = 1320.471, step = 1400 (0.439 sec)
# INFO:tensorflow:global_step/sec: 219.039
# INFO:tensorflow:loss = 1250.0099, step = 1500 (0.457 sec)
# INFO:tensorflow:global_step/sec: 209.97
# INFO:tensorflow:loss = 1260.4624, step = 1600 (0.478 sec)
# INFO:tensorflow:global_step/sec: 234.418
# INFO:tensorflow:loss = 1213.1069, step = 1700 (0.425 sec)
# INFO:tensorflow:global_step/sec: 231.148
# INFO:tensorflow:loss = 1160.8774, step = 1800 (0.433 sec)
# INFO:tensorflow:global_step/sec: 234.954
# INFO:tensorflow:loss = 1236.1218, step = 1900 (0.425 sec)
# INFO:tensorflow:global_step/sec: 238.555
# INFO:tensorflow:loss = 1233.792, step = 2000 (0.421 sec)
# INFO:tensorflow:global_step/sec: 236.92
# INFO:tensorflow:loss = 1162.3616, step = 2100 (0.421 sec)
# INFO:tensorflow:global_step/sec: 249.235
# INFO:tensorflow:loss = 1261.3422, step = 2200 (0.401 sec)
# INFO:tensorflow:global_step/sec: 245.704
# INFO:tensorflow:loss = 1185.8666, step = 2300 (0.407 sec)
# INFO:tensorflow:global_step/sec: 241.057
# INFO:tensorflow:loss = 1240.7766, step = 2400 (0.415 sec)
# INFO:tensorflow:global_step/sec: 241.275
# INFO:tensorflow:loss = 1198.1344, step = 2500 (0.414 sec)
# INFO:tensorflow:global_step/sec: 235.512
# INFO:tensorflow:loss = 1197.155, step = 2600 (0.426 sec)
# INFO:tensorflow:global_step/sec: 242.834
# INFO:tensorflow:loss = 1165.2463, step = 2700 (0.411 sec)
# INFO:tensorflow:global_step/sec: 241.083
# INFO:tensorflow:loss = 1187.5211, step = 2800 (0.415 sec)
# INFO:tensorflow:global_step/sec: 233.519
# INFO:tensorflow:loss = 1095.6101, step = 2900 (0.428 sec)
# INFO:tensorflow:global_step/sec: 226.533
# INFO:tensorflow:loss = 991.3839, step = 3000 (0.442 sec)
# INFO:tensorflow:global_step/sec: 229.27
# INFO:tensorflow:loss = 993.8049, step = 3100 (0.436 sec)
# INFO:tensorflow:global_step/sec: 228.717
# INFO:tensorflow:loss = 1093.7219, step = 3200 (0.437 sec)
# INFO:tensorflow:global_step/sec: 237.795
# INFO:tensorflow:loss = 1069.7015, step = 3300 (0.420 sec)
# INFO:tensorflow:global_step/sec: 241.704
# INFO:tensorflow:loss = 1024.4697, step = 3400 (0.414 sec)
# INFO:tensorflow:global_step/sec: 224.891
# INFO:tensorflow:loss = 1089.9142, step = 3500 (0.445 sec)
# INFO:tensorflow:global_step/sec: 226.957
# INFO:tensorflow:loss = 1018.67847, step = 3600 (0.440 sec)
# INFO:tensorflow:global_step/sec: 229.149
# INFO:tensorflow:loss = 1038.1248, step = 3700 (0.437 sec)
# INFO:tensorflow:global_step/sec: 223.22
# INFO:tensorflow:loss = 961.67676, step = 3800 (0.448 sec)
# INFO:tensorflow:global_step/sec: 232.365
# INFO:tensorflow:loss = 944.5348, step = 3900 (0.430 sec)
# INFO:tensorflow:global_step/sec: 226.179
# INFO:tensorflow:loss = 910.2434, step = 4000 (0.443 sec)
# INFO:tensorflow:global_step/sec: 216.426
# INFO:tensorflow:loss = 997.45874, step = 4100 (0.462 sec)
# INFO:tensorflow:global_step/sec: 213.406
# INFO:tensorflow:loss = 933.74243, step = 4200 (0.468 sec)
# INFO:tensorflow:global_step/sec: 206.797
# INFO:tensorflow:loss = 978.5456, step = 4300 (0.483 sec)
# INFO:tensorflow:global_step/sec: 189.061
# INFO:tensorflow:loss = 963.09406, step = 4400 (0.529 sec)
# INFO:tensorflow:global_step/sec: 211.701
# INFO:tensorflow:loss = 945.4632, step = 4500 (0.474 sec)
# INFO:tensorflow:global_step/sec: 214.899
# INFO:tensorflow:loss = 936.03235, step = 4600 (0.464 sec)
# INFO:tensorflow:global_step/sec: 195.119
# INFO:tensorflow:loss = 872.01025, step = 4700 (0.513 sec)
# INFO:tensorflow:global_step/sec: 211.472
# INFO:tensorflow:loss = 849.31305, step = 4800 (0.473 sec)
# INFO:tensorflow:global_step/sec: 224.95
# INFO:tensorflow:loss = 912.9878, step = 4900 (0.446 sec)
# INFO:tensorflow:global_step/sec: 218.018
# INFO:tensorflow:loss = 836.3109, step = 5000 (0.457 sec)
# INFO:tensorflow:global_step/sec: 233.603
# INFO:tensorflow:loss = 876.7561, step = 5100 (0.428 sec)
# INFO:tensorflow:global_step/sec: 201.823
# INFO:tensorflow:loss = 825.44214, step = 5200 (0.497 sec)
# INFO:tensorflow:global_step/sec: 193.2
# INFO:tensorflow:loss = 905.7927, step = 5300 (0.516 sec)
# INFO:tensorflow:global_step/sec: 183.035
# INFO:tensorflow:loss = 903.2189, step = 5400 (0.547 sec)
# INFO:tensorflow:global_step/sec: 213.489
# INFO:tensorflow:loss = 791.0683, step = 5500 (0.470 sec)
# INFO:tensorflow:global_step/sec: 222.781
# INFO:tensorflow:loss = 810.9672, step = 5600 (0.447 sec)
# INFO:tensorflow:global_step/sec: 212.611
# INFO:tensorflow:loss = 776.9982, step = 5700 (0.470 sec)
# INFO:tensorflow:global_step/sec: 193.615
# INFO:tensorflow:loss = 779.54535, step = 5800 (0.516 sec)
# INFO:tensorflow:global_step/sec: 224.86
# INFO:tensorflow:loss = 762.6665, step = 5900 (0.445 sec)
# INFO:tensorflow:global_step/sec: 217.538
# INFO:tensorflow:loss = 729.4812, step = 6000 (0.460 sec)
# INFO:tensorflow:global_step/sec: 211.183
# INFO:tensorflow:loss = 771.97656, step = 6100 (0.475 sec)
# INFO:tensorflow:global_step/sec: 178.387
# INFO:tensorflow:loss = 797.0541, step = 6200 (0.560 sec)
# INFO:tensorflow:global_step/sec: 195.009
# INFO:tensorflow:loss = 757.57385, step = 6300 (0.514 sec)
# INFO:tensorflow:global_step/sec: 211.963
# INFO:tensorflow:loss = 711.54614, step = 6400 (0.471 sec)
# INFO:tensorflow:global_step/sec: 211.11
# INFO:tensorflow:loss = 724.5812, step = 6500 (0.475 sec)
# INFO:tensorflow:global_step/sec: 178.963
# INFO:tensorflow:loss = 771.73083, step = 6600 (0.557 sec)
# INFO:tensorflow:global_step/sec: 204.635
# INFO:tensorflow:loss = 801.6129, step = 6700 (0.490 sec)
# INFO:tensorflow:global_step/sec: 218.065
# INFO:tensorflow:loss = 766.47107, step = 6800 (0.457 sec)
# INFO:tensorflow:global_step/sec: 223.511
# INFO:tensorflow:loss = 703.9685, step = 6900 (0.447 sec)
# INFO:tensorflow:global_step/sec: 231.548
# INFO:tensorflow:loss = 760.68713, step = 7000 (0.433 sec)
# INFO:tensorflow:global_step/sec: 237.364
# INFO:tensorflow:loss = 752.9973, step = 7100 (0.420 sec)
# INFO:tensorflow:global_step/sec: 250.224
# INFO:tensorflow:loss = 684.02185, step = 7200 (0.399 sec)
# INFO:tensorflow:global_step/sec: 234.101
# INFO:tensorflow:loss = 695.0045, step = 7300 (0.427 sec)
# INFO:tensorflow:global_step/sec: 217.464
# INFO:tensorflow:loss = 676.93933, step = 7400 (0.461 sec)
# INFO:tensorflow:global_step/sec: 193.934
# INFO:tensorflow:loss = 712.48157, step = 7500 (0.515 sec)
# INFO:tensorflow:global_step/sec: 177.567
# INFO:tensorflow:loss = 680.2207, step = 7600 (0.563 sec)
# INFO:tensorflow:global_step/sec: 183.696
# INFO:tensorflow:loss = 695.1168, step = 7700 (0.544 sec)
# INFO:tensorflow:global_step/sec: 205.982
# INFO:tensorflow:loss = 682.16833, step = 7800 (0.485 sec)
# INFO:tensorflow:global_step/sec: 196.325
# INFO:tensorflow:loss = 213.10345, step = 7900 (0.509 sec)
# INFO:tensorflow:global_step/sec: 220.478
# INFO:tensorflow:loss = 238.25949, step = 8000 (0.455 sec)
# INFO:tensorflow:global_step/sec: 219.521
# INFO:tensorflow:loss = 254.40271, step = 8100 (0.455 sec)
# INFO:tensorflow:global_step/sec: 225.844
# INFO:tensorflow:loss = 263.8411, step = 8200 (0.442 sec)
# INFO:tensorflow:global_step/sec: 205.586
# INFO:tensorflow:loss = 317.84634, step = 8300 (0.487 sec)
# INFO:tensorflow:global_step/sec: 221.369
# INFO:tensorflow:loss = 347.77164, step = 8400 (0.451 sec)
# INFO:tensorflow:global_step/sec: 226.026
# INFO:tensorflow:loss = 332.79144, step = 8500 (0.442 sec)
# INFO:tensorflow:global_step/sec: 222.903
# INFO:tensorflow:loss = 367.94528, step = 8600 (0.449 sec)
# INFO:tensorflow:global_step/sec: 223.312
# INFO:tensorflow:loss = 339.06116, step = 8700 (0.449 sec)
# INFO:tensorflow:global_step/sec: 228.04
# INFO:tensorflow:loss = 414.11487, step = 8800 (0.437 sec)
# INFO:tensorflow:global_step/sec: 229.469
# INFO:tensorflow:loss = 349.7162, step = 8900 (0.436 sec)
# INFO:tensorflow:global_step/sec: 223.06
# INFO:tensorflow:loss = 376.17795, step = 9000 (0.450 sec)
# INFO:tensorflow:global_step/sec: 202.523
# INFO:tensorflow:loss = 379.42023, step = 9100 (0.493 sec)
# INFO:tensorflow:global_step/sec: 215.895
# INFO:tensorflow:loss = 432.8895, step = 9200 (0.463 sec)
# INFO:tensorflow:global_step/sec: 209.021
# INFO:tensorflow:loss = 416.11758, step = 9300 (0.479 sec)
# INFO:tensorflow:global_step/sec: 198.947
# INFO:tensorflow:loss = 396.56, step = 9400 (0.502 sec)
# INFO:tensorflow:global_step/sec: 203.903
# INFO:tensorflow:loss = 395.4591, step = 9500 (0.490 sec)
# INFO:tensorflow:global_step/sec: 217.659
# INFO:tensorflow:loss = 424.34094, step = 9600 (0.459 sec)
# INFO:tensorflow:global_step/sec: 224.167
# INFO:tensorflow:loss = 446.91345, step = 9700 (0.447 sec)
# INFO:tensorflow:global_step/sec: 232.573
# INFO:tensorflow:loss = 382.94336, step = 9800 (0.428 sec)
# INFO:tensorflow:global_step/sec: 223.684
# INFO:tensorflow:loss = 447.42963, step = 9900 (0.448 sec)
# INFO:tensorflow:global_step/sec: 228.959
# INFO:tensorflow:loss = 412.80725, step = 10000 (0.436 sec)
# INFO:tensorflow:global_step/sec: 215.364
# INFO:tensorflow:loss = 455.67392, step = 10100 (0.464 sec)
# INFO:tensorflow:global_step/sec: 229.127
# INFO:tensorflow:loss = 457.87317, step = 10200 (0.437 sec)
# INFO:tensorflow:global_step/sec: 222.28
# INFO:tensorflow:loss = 438.06683, step = 10300 (0.450 sec)
# INFO:tensorflow:global_step/sec: 204.54
# INFO:tensorflow:loss = 462.00256, step = 10400 (0.490 sec)
# INFO:tensorflow:global_step/sec: 192.194
# INFO:tensorflow:loss = 476.39627, step = 10500 (0.519 sec)
# INFO:tensorflow:global_step/sec: 189.861
# INFO:tensorflow:loss = 436.07104, step = 10600 (0.527 sec)
# INFO:tensorflow:global_step/sec: 188.49
# INFO:tensorflow:loss = 466.59137, step = 10700 (0.531 sec)
# INFO:tensorflow:global_step/sec: 202.693
# INFO:tensorflow:loss = 449.01968, step = 10800 (0.492 sec)
# INFO:tensorflow:global_step/sec: 192.389
# INFO:tensorflow:loss = 469.48172, step = 10900 (0.519 sec)
# INFO:tensorflow:global_step/sec: 205.652
# INFO:tensorflow:loss = 436.4101, step = 11000 (0.488 sec)
# INFO:tensorflow:global_step/sec: 196.555
# INFO:tensorflow:loss = 448.0473, step = 11100 (0.508 sec)
# INFO:tensorflow:global_step/sec: 184.723
# INFO:tensorflow:loss = 419.1396, step = 11200 (0.541 sec)
# INFO:tensorflow:global_step/sec: 178.48
# INFO:tensorflow:loss = 429.2494, step = 11300 (0.562 sec)
# INFO:tensorflow:global_step/sec: 182.063
# INFO:tensorflow:loss = 462.98596, step = 11400 (0.547 sec)
# INFO:tensorflow:global_step/sec: 185.405
# INFO:tensorflow:loss = 424.53345, step = 11500 (0.539 sec)
# INFO:tensorflow:global_step/sec: 182.247
# INFO:tensorflow:loss = 478.08252, step = 11600 (0.550 sec)
# INFO:tensorflow:global_step/sec: 189.172
# INFO:tensorflow:loss = 463.1827, step = 11700 (0.528 sec)
# INFO:tensorflow:global_step/sec: 205.941
# INFO:tensorflow:loss = 479.38226, step = 11800 (0.485 sec)
# INFO:tensorflow:global_step/sec: 180.8
# INFO:tensorflow:loss = 408.6324, step = 11900 (0.556 sec)
# INFO:tensorflow:global_step/sec: 188.958
# INFO:tensorflow:loss = 445.30457, step = 12000 (0.527 sec)
# INFO:tensorflow:global_step/sec: 200.884
# INFO:tensorflow:loss = 450.5206, step = 12100 (0.498 sec)
# INFO:tensorflow:global_step/sec: 194.327
# INFO:tensorflow:loss = 424.37866, step = 12200 (0.515 sec)
# INFO:tensorflow:global_step/sec: 208.554
# INFO:tensorflow:loss = 463.8873, step = 12300 (0.480 sec)
# INFO:tensorflow:global_step/sec: 221.138
# INFO:tensorflow:loss = 492.40775, step = 12400 (0.452 sec)
# INFO:tensorflow:global_step/sec: 229.11
# INFO:tensorflow:loss = 465.6135, step = 12500 (0.436 sec)
# INFO:tensorflow:global_step/sec: 222.198
# INFO:tensorflow:loss = 471.30643, step = 12600 (0.450 sec)
# INFO:tensorflow:global_step/sec: 214.207
# INFO:tensorflow:loss = 430.52472, step = 12700 (0.467 sec)
# INFO:tensorflow:global_step/sec: 222.897
# INFO:tensorflow:loss = 450.36554, step = 12800 (0.448 sec)
# INFO:tensorflow:global_step/sec: 204.642
# INFO:tensorflow:loss = 455.42273, step = 12900 (0.489 sec)
# INFO:tensorflow:global_step/sec: 225.222
# INFO:tensorflow:loss = 433.86716, step = 13000 (0.444 sec)
# INFO:tensorflow:global_step/sec: 226.286
# INFO:tensorflow:loss = 480.20392, step = 13100 (0.442 sec)
# INFO:tensorflow:global_step/sec: 217.999
# INFO:tensorflow:loss = 429.44733, step = 13200 (0.459 sec)
# INFO:tensorflow:global_step/sec: 208.816
# INFO:tensorflow:loss = 449.2091, step = 13300 (0.479 sec)
# INFO:tensorflow:global_step/sec: 214.046
# INFO:tensorflow:loss = 438.45218, step = 13400 (0.468 sec)
# INFO:tensorflow:global_step/sec: 202.494
# INFO:tensorflow:loss = 473.16522, step = 13500 (0.494 sec)
# INFO:tensorflow:global_step/sec: 200.667
# INFO:tensorflow:loss = 454.15295, step = 13600 (0.498 sec)
# INFO:tensorflow:global_step/sec: 200.06
# INFO:tensorflow:loss = 447.38815, step = 13700 (0.501 sec)
# INFO:tensorflow:global_step/sec: 200.387
# INFO:tensorflow:loss = 451.46802, step = 13800 (0.498 sec)
# INFO:tensorflow:global_step/sec: 212.333
# INFO:tensorflow:loss = 415.02158, step = 13900 (0.471 sec)
# INFO:tensorflow:global_step/sec: 217.942
# INFO:tensorflow:loss = 477.11353, step = 14000 (0.460 sec)
# INFO:tensorflow:global_step/sec: 234.041
# INFO:tensorflow:loss = 442.51498, step = 14100 (0.426 sec)
# INFO:tensorflow:global_step/sec: 236.32
# INFO:tensorflow:loss = 423.7152, step = 14200 (0.423 sec)
# INFO:tensorflow:global_step/sec: 237.339
# INFO:tensorflow:loss = 468.63876, step = 14300 (0.421 sec)
# INFO:tensorflow:global_step/sec: 240.855
# INFO:tensorflow:loss = 414.81573, step = 14400 (0.415 sec)
# INFO:tensorflow:global_step/sec: 238.365
# INFO:tensorflow:loss = 419.92657, step = 14500 (0.420 sec)
# INFO:tensorflow:global_step/sec: 232.987
# INFO:tensorflow:loss = 425.84604, step = 14600 (0.429 sec)
# INFO:tensorflow:global_step/sec: 216.001
# INFO:tensorflow:loss = 446.49478, step = 14700 (0.464 sec)
# INFO:tensorflow:global_step/sec: 204.849
# INFO:tensorflow:loss = 441.19046, step = 14800 (0.487 sec)
# INFO:tensorflow:global_step/sec: 216.446
# INFO:tensorflow:loss = 495.85443, step = 14900 (0.463 sec)
# INFO:tensorflow:global_step/sec: 228.223
# INFO:tensorflow:loss = 475.19983, step = 15000 (0.438 sec)
# INFO:tensorflow:global_step/sec: 220.215
# INFO:tensorflow:loss = 453.32266, step = 15100 (0.454 sec)
# INFO:tensorflow:global_step/sec: 212.263
# INFO:tensorflow:loss = 450.11133, step = 15200 (0.471 sec)
# INFO:tensorflow:global_step/sec: 204.835
# INFO:tensorflow:loss = 432.18283, step = 15300 (0.489 sec)
# INFO:tensorflow:global_step/sec: 211.786
# INFO:tensorflow:loss = 430.9337, step = 15400 (0.472 sec)
# INFO:tensorflow:global_step/sec: 200.086
# INFO:tensorflow:loss = 435.05902, step = 15500 (0.500 sec)
# INFO:tensorflow:global_step/sec: 213.43
# INFO:tensorflow:loss = 414.26248, step = 15600 (0.470 sec)
# INFO:tensorflow:global_step/sec: 230.369
# INFO:tensorflow:loss = 209.26764, step = 15700 (0.433 sec)
# INFO:tensorflow:global_step/sec: 241.674
# INFO:tensorflow:loss = 221.82164, step = 15800 (0.414 sec)
# INFO:tensorflow:global_step/sec: 240.589
# INFO:tensorflow:loss = 245.2333, step = 15900 (0.416 sec)
# INFO:tensorflow:global_step/sec: 241.023
# INFO:tensorflow:loss = 258.69107, step = 16000 (0.415 sec)
# INFO:tensorflow:global_step/sec: 248.592
# INFO:tensorflow:loss = 253.3175, step = 16100 (0.404 sec)
# INFO:tensorflow:global_step/sec: 248.852
# INFO:tensorflow:loss = 288.3876, step = 16200 (0.401 sec)
# INFO:tensorflow:global_step/sec: 249.439
# INFO:tensorflow:loss = 285.08374, step = 16300 (0.401 sec)
# INFO:tensorflow:global_step/sec: 238.598
# INFO:tensorflow:loss = 301.48886, step = 16400 (0.419 sec)
# INFO:tensorflow:global_step/sec: 100.618
# INFO:tensorflow:loss = 467.9601, step = 16500 (0.994 sec)
# INFO:tensorflow:global_step/sec: 187.54
# INFO:tensorflow:loss = 427.2437, step = 16600 (0.533 sec)
# INFO:tensorflow:global_step/sec: 193.155
# INFO:tensorflow:loss = 480.31305, step = 16700 (0.517 sec)
# INFO:tensorflow:global_step/sec: 186.149
# INFO:tensorflow:loss = 474.43472, step = 16800 (0.537 sec)
# INFO:tensorflow:global_step/sec: 187.868
# INFO:tensorflow:loss = 488.2945, step = 16900 (0.532 sec)
# INFO:tensorflow:global_step/sec: 191.227
# INFO:tensorflow:loss = 439.58405, step = 17000 (0.524 sec)
# INFO:tensorflow:global_step/sec: 176.447
# INFO:tensorflow:loss = 419.41617, step = 17100 (0.567 sec)
# INFO:tensorflow:global_step/sec: 174.115
# INFO:tensorflow:loss = 514.8064, step = 17200 (0.574 sec)
# INFO:tensorflow:global_step/sec: 173.545
# INFO:tensorflow:loss = 458.7086, step = 17300 (0.576 sec)
# INFO:tensorflow:global_step/sec: 201.616
# INFO:tensorflow:loss = 477.17355, step = 17400 (0.496 sec)
# INFO:tensorflow:global_step/sec: 204.342
# INFO:tensorflow:loss = 444.46933, step = 17500 (0.492 sec)
# INFO:tensorflow:global_step/sec: 198.936
# INFO:tensorflow:loss = 440.1775, step = 17600 (0.500 sec)
# INFO:tensorflow:global_step/sec: 205.874
# INFO:tensorflow:loss = 462.96918, step = 17700 (0.485 sec)
# INFO:tensorflow:global_step/sec: 199.298
# INFO:tensorflow:loss = 499.04102, step = 17800 (0.502 sec)
# INFO:tensorflow:global_step/sec: 203.47
# INFO:tensorflow:loss = 477.40253, step = 17900 (0.491 sec)
# INFO:tensorflow:global_step/sec: 212.091
# INFO:tensorflow:loss = 494.31366, step = 18000 (0.471 sec)
# INFO:tensorflow:global_step/sec: 201.095
# INFO:tensorflow:loss = 449.82745, step = 18100 (0.498 sec)
# INFO:tensorflow:global_step/sec: 204.623
# INFO:tensorflow:loss = 440.05933, step = 18200 (0.489 sec)
# INFO:tensorflow:global_step/sec: 209.678
# INFO:tensorflow:loss = 500.63986, step = 18300 (0.477 sec)
# INFO:tensorflow:global_step/sec: 216.433
# INFO:tensorflow:loss = 486.41315, step = 18400 (0.462 sec)
# INFO:tensorflow:global_step/sec: 184.797
# INFO:tensorflow:loss = 502.55783, step = 18500 (0.542 sec)
# INFO:tensorflow:global_step/sec: 160.197
# INFO:tensorflow:loss = 491.01486, step = 18600 (0.623 sec)
# INFO:tensorflow:global_step/sec: 152.976
# INFO:tensorflow:loss = 447.00443, step = 18700 (0.655 sec)
# INFO:tensorflow:global_step/sec: 155.566
# INFO:tensorflow:loss = 440.5332, step = 18800 (0.643 sec)
# INFO:tensorflow:global_step/sec: 152.936
# INFO:tensorflow:loss = 463.62402, step = 18900 (0.656 sec)
# INFO:tensorflow:global_step/sec: 151.245
# INFO:tensorflow:loss = 466.7071, step = 19000 (0.664 sec)
# INFO:tensorflow:global_step/sec: 160.702
# INFO:tensorflow:loss = 470.6454, step = 19100 (0.618 sec)
# INFO:tensorflow:global_step/sec: 165.387
# INFO:tensorflow:loss = 484.7456, step = 19200 (0.604 sec)
# INFO:tensorflow:global_step/sec: 169.15
# INFO:tensorflow:loss = 491.7606, step = 19300 (0.592 sec)
# INFO:tensorflow:global_step/sec: 182.135
# INFO:tensorflow:loss = 465.78094, step = 19400 (0.548 sec)
# INFO:tensorflow:global_step/sec: 189.868
# INFO:tensorflow:loss = 511.25412, step = 19500 (0.527 sec)
# INFO:tensorflow:global_step/sec: 192.114
# INFO:tensorflow:loss = 503.7791, step = 19600 (0.523 sec)
# INFO:tensorflow:global_step/sec: 193.157
# INFO:tensorflow:loss = 498.48804, step = 19700 (0.515 sec)
# INFO:tensorflow:global_step/sec: 185.517
# INFO:tensorflow:loss = 507.08206, step = 19800 (0.539 sec)
# INFO:tensorflow:global_step/sec: 202.629
# INFO:tensorflow:loss = 477.3174, step = 19900 (0.493 sec)
# INFO:tensorflow:global_step/sec: 204.478
# INFO:tensorflow:loss = 468.6066, step = 20000 (0.493 sec)
# INFO:tensorflow:global_step/sec: 211.365
# INFO:tensorflow:loss = 466.9131, step = 20100 (0.469 sec)
# INFO:tensorflow:global_step/sec: 214.667
# INFO:tensorflow:loss = 437.12827, step = 20200 (0.466 sec)
# INFO:tensorflow:global_step/sec: 212.082
# INFO:tensorflow:loss = 466.99152, step = 20300 (0.472 sec)
# INFO:tensorflow:global_step/sec: 206.486
# INFO:tensorflow:loss = 516.46277, step = 20400 (0.484 sec)
# INFO:tensorflow:global_step/sec: 202.085
# INFO:tensorflow:loss = 478.4073, step = 20500 (0.500 sec)
# INFO:tensorflow:global_step/sec: 201.77
# INFO:tensorflow:loss = 445.4349, step = 20600 (0.491 sec)
# INFO:tensorflow:global_step/sec: 197.486
# INFO:tensorflow:loss = 486.19125, step = 20700 (0.506 sec)
# INFO:tensorflow:global_step/sec: 201.644
# INFO:tensorflow:loss = 510.02786, step = 20800 (0.496 sec)
# INFO:tensorflow:global_step/sec: 181.497
# INFO:tensorflow:loss = 494.02884, step = 20900 (0.551 sec)
# INFO:tensorflow:global_step/sec: 184.876
# INFO:tensorflow:loss = 510.88, step = 21000 (0.541 sec)
# INFO:tensorflow:global_step/sec: 182.486
# INFO:tensorflow:loss = 428.27365, step = 21100 (0.548 sec)
# INFO:tensorflow:global_step/sec: 178
# INFO:tensorflow:loss = 504.5646, step = 21200 (0.562 sec)
# INFO:tensorflow:global_step/sec: 187.924
# INFO:tensorflow:loss = 482.23434, step = 21300 (0.532 sec)
# INFO:tensorflow:global_step/sec: 185.133
# INFO:tensorflow:loss = 481.51053, step = 21400 (0.540 sec)
# INFO:tensorflow:global_step/sec: 183.42
# INFO:tensorflow:loss = 445.52228, step = 21500 (0.545 sec)
# INFO:tensorflow:global_step/sec: 187.75
# INFO:tensorflow:loss = 469.8447, step = 21600 (0.533 sec)
# INFO:tensorflow:global_step/sec: 205.683
# INFO:tensorflow:loss = 507.37323, step = 21700 (0.486 sec)
# INFO:tensorflow:global_step/sec: 204.526
# INFO:tensorflow:loss = 490.19412, step = 21800 (0.489 sec)
# INFO:tensorflow:global_step/sec: 216.002
# INFO:tensorflow:loss = 499.43527, step = 21900 (0.468 sec)
# INFO:tensorflow:global_step/sec: 210.865
# INFO:tensorflow:loss = 525.61163, step = 22000 (0.470 sec)
# INFO:tensorflow:global_step/sec: 210.081
# INFO:tensorflow:loss = 503.64816, step = 22100 (0.476 sec)
# INFO:tensorflow:global_step/sec: 211.904
# INFO:tensorflow:loss = 487.39618, step = 22200 (0.472 sec)
# INFO:tensorflow:global_step/sec: 209.978
# INFO:tensorflow:loss = 484.3354, step = 22300 (0.476 sec)
# INFO:tensorflow:global_step/sec: 209.813
# INFO:tensorflow:loss = 453.09445, step = 22400 (0.476 sec)
# INFO:tensorflow:global_step/sec: 189.534
# INFO:tensorflow:loss = 465.63815, step = 22500 (0.528 sec)
# INFO:tensorflow:global_step/sec: 169.215
# INFO:tensorflow:loss = 467.25247, step = 22600 (0.591 sec)
# INFO:tensorflow:global_step/sec: 185.197
# INFO:tensorflow:loss = 450.98648, step = 22700 (0.540 sec)
# INFO:tensorflow:global_step/sec: 174.928
# INFO:tensorflow:loss = 482.92993, step = 22800 (0.573 sec)
# INFO:tensorflow:global_step/sec: 154.734
# INFO:tensorflow:loss = 484.8272, step = 22900 (0.646 sec)
# INFO:tensorflow:global_step/sec: 162.07
# INFO:tensorflow:loss = 486.84445, step = 23000 (0.617 sec)
# INFO:tensorflow:global_step/sec: 174.633
# INFO:tensorflow:loss = 487.83853, step = 23100 (0.573 sec)
# INFO:tensorflow:global_step/sec: 165.446
# INFO:tensorflow:loss = 480.36212, step = 23200 (0.603 sec)
# INFO:tensorflow:global_step/sec: 165.65
# INFO:tensorflow:loss = 433.54636, step = 23300 (0.605 sec)
# INFO:tensorflow:global_step/sec: 158.872
# INFO:tensorflow:loss = 494.57104, step = 23400 (0.628 sec)
# INFO:tensorflow:Saving checkpoints for 23439 into ./poeem_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 201.46193.

# %% [markdown]
# ### Export item embedding and build index

# %% [markdown]
# Though theoretically *poeem* does not need to build an index, we can still optionally build one to persist the embedding index into disk. Since *poeem* indexing layer has already done coarse quantization and product quantization internally, the index building just needs to export those values into an index file as follows.

# %%
def predict_input_fn():
    dataset = tf.data.Dataset.from_tensor_slices({'query': np.arange(VOCAB_SIZE), 'item': np.arange(VOCAB_SIZE)})
    dataset = dataset.batch(VOCAB_SIZE)
    return dataset

poeem_model = tf.estimator.Estimator(model_fn=poeem_model_fn, model_dir=MODEL_DIR, 
                                     params={'item_predict': True})
results = list(poeem_model.predict(input_fn=predict_input_fn))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './poeem_model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5836a4a710>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./poeem_model/model.ckpt-23439
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# Collect all the data we need to write into an index file

# %%
item_coarse_code = np.array([e['item_coarse_code'] for e in results])
item_code = np.array([e['item_code'] for e in results])
item_norm = np.array([e['item_norm'] for e in results])
item_id = np.arange(VOCAB_SIZE)
coarse_codebook = tf.train.load_variable(MODEL_DIR, 'coarse_centroids')
codebook = tf.train.load_variable(MODEL_DIR, 'centroids_k')

INDEX_FILE = './poeem.idx'
poeem.indexing.write_index_file(INDEX_FILE, codebook, item_id, item_norm, item_code, 
                                coarse_codebook, item_coarse_code, use_residual=True)

# %% [markdown]
# ### Poeem nearest neighbor search

# %% [markdown]
# *poeem* ANN search would be in an end-to-end fashion, i.e., input a query and output its nearest neighbor items directly. The most simplest setup would be as follows

# %%
poeem_model = tf.estimator.Estimator(model_fn=poeem_model_fn, model_dir=MODEL_DIR, 
                                     params={'item_search': True, 'index_file': INDEX_FILE, 
                                             'topk': 100, 'nprobe': 1, 'metric_type': 0})
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './poeem_model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5836a4a908>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# To measure *poeem* rerieval accuracy, we first compute retrieval results for all queries.

# %%
def search_input_fn():
    dataset = tf.data.Dataset.from_tensor_slices({'query': np.arange(VOCAB_SIZE)})
    dataset = dataset.batch(VOCAB_SIZE)
    return dataset

results = list(poeem_model.predict(input_fn=search_input_fn))
neighbors = np.array([e['neighbors'] for e in results])
scores = np.array([e['scores'] for e in results])
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/poeem/ops/python/search.py:36: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /home/wenyun.yang/tf/lib64/python3.6/site-packages/poeem/ops/python/search.py:36: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./poeem_model/model.ckpt-23439
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# Follows the search function interface as above Brute Force and Faiss search, so we can reuse the precision_at_k utitity function.

# %%
def poeem_search(query_id, items, k=100):
    return neighbors[query_id, :k]

# %%
precision_at_100 = [precision_at_k(poeem_search, i, None, k=100) for i in range(VOCAB_SIZE)]
print("overall precision@100 = ", np.mean(precision_at_100))
# Out:
# overall precision@100 =  0.9804640000000001

# %% [markdown]
# **Observation**: Note that Poeem could reach higher retrieval accuracy than Faiss, by jointly learning the embedding index and retrieval model.
#
# This is a simple example as a quick rampup for beginners. For more rigorous experimental results to draw conclusions, please checkout our SIGIR paper.
